# %% [markdown]
# # Working asset trading bot that automatically places orders on an exchange called Oanda (we use a demo account and paper money) according to a random strategy.
#
# Note: the exchange is not 100% reliable so if the code doesn't run the first time, try again. Also, dependency issues may arise depending on the machine used.
#
# API dependencies:
# - oandapy
# - v20

# %%
import sys
# !{sys.executable} -m pip install git+https://github.com/oanda/oandapy.git
# !{sys.executable} -m pip install git+https://github.com/oanda/v20-python.git
# !{sys.executable} -m pip install git+https://github.com/oanda/v20-python-samples.git
# !{sys.executable} -m pip install v20
import pandas as pd # Collect and manipulate historical data
import oandapy as opy # Implement basic API
import v20 # Implement rad API
import urllib # Acquire Oanda site xml data
import re # Discover available asset types and trading pairs
import random # Generate awesome numbers
import time # tick tock
# Out:
# Collecting git+https://github.com/oanda/oandapy.git
#   Cloning https://github.com/oanda/oandapy.git to c:\users\freddi~1\appdata\local\temp\pip-cffsgecv-build
#   Requirement already satisfied (use --upgrade to upgrade): oandapy==0.1 from git+https://github.com/oanda/oandapy.git in c:\programdata\anaconda3\lib\site-packages
# Requirement already satisfied: requests in c:\users\freddie bussler (from oandapy==0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->oandapy==0.1)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->oandapy==0.1)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->oandapy==0.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->oandapy==0.1)
# Collecting git+https://github.com/oanda/v20-python.git
#   Cloning https://github.com/oanda/v20-python.git to c:\users\freddi~1\appdata\local\temp\pip-qwstd90h-build
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\ProgramData\Anaconda3\lib\tokenize.py", line 452, in open
#         buffer = _builtin_open(filename, 'rb')
#     FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\FREDDI~1\\AppData\\Local\\Temp\\pip-qwstd90h-build\\setup.py'
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in C:\Users\FREDDI~1\AppData\Local\Temp\pip-qwstd90h-build\
# Collecting git+https://github.com/oanda/v20-python-samples.git
#   Cloning https://github.com/oanda/v20-python-samples.git to c:\users\freddi~1\appdata\local\temp\pip-w9k9eq18-build
#   Requirement already satisfied (use --upgrade to upgrade): v20-python-samples==0.1.1 from git+https://github.com/oanda/v20-python-samples.git in c:\users\freddie bussler\v20-python-samples\src
# Requirement already satisfied: v20 in c:\programdata\anaconda3\lib\site-packages
# Requirement already satisfied: requests in c:\users\freddie bussler (from v20)
# Requirement already satisfied: ujson in c:\programdata\anaconda3\lib\site-packages (from v20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->v20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->v20)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->v20)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->v20)

# %%
class Oanda(object):
    """Pulls in custom data according to specs, converts to a Pandas DataFrame and cleans it!"""
    api = v20.Context('api-fxpractice.oanda.com','443',token='21928d31a473366fd2c27689849a3e6a-c81367d6ecf5be2be2a0b5c46c61bc3f')
    oanda = opy.API(environment='practice',access_token='21928d31a473366fd2c27689849a3e6a-c81367d6ecf5be2be2a0b5c46c61bc3f')
    def __init__(self, instrument, start, granularity, count):
        self.__accountID = '101-001-7843068-001' # unique to our paper trading account, does not change
        self.instrument = instrument # what asset pair to trade, i.e. EUR_USD
        self.start = start # start date for data collection
        self.granularity = granularity # how fine the data is (i.e. hourly, minutely)
        self.count = count # number of data points

    @property
    def attr(self):  
        return str(self.__accountID)

    @attr.setter
    def attr(self, value):
        self.__accountID = '101-001-7843068-001'

    def acquire_data(self): 
        # For example: Get EUR_USD data since May 15 2000, 5000 rows at 1 hr granularity (5000 hrs)
        data = Oanda.oanda.get_history(instrument = self.instrument, start = self.start, count = self.count, granularity = self.granularity)
        df = pd.DataFrame(data['candles']).set_index('time') # Converts data to Pandas DataFrame
        df.index = pd.DatetimeIndex(df.index) # Sets index to DateTime object

        end = str((df.index[-1]).date()) # next start date
        # Makes 5 API calls, each with <count> datapoints received, append DataFrames together
        for five_thousand_period in range(5): # useful if user wants more than max single call data
            data = Oanda.oanda.get_history(instrument = self.instrument, start = end, count = self.count, granularity = self.granularity)
            next_df = pd.DataFrame(data['candles']).set_index('time')
            next_df.index = pd.DatetimeIndex(next_df.index)
            end = str((next_df.index[-1]).date()) # next start date
            df = df.append(next_df)
        df.to_csv(self.instrument + '.csv') # turn into a csv
        
    def normalize_return_data(self):
        df = pd.DataFrame()
        df = df.from_csv(self.instrument + '.csv').drop_duplicates() # read from local dir and drop data collected for same timestamps
        # divide df by row 1 (norm) so first entry is 1 for all data and subsequent cells w/in columns are respective pct gains
        df['closeAsk'] = df['closeAsk'].divide(df['closeAsk'].iloc[0])
        print("Custom dataset loaded.")
        return df

instrument = input('What pair would you like to trade (i.e. EUR_USD): ')
start = input("Enter the start date of data you'd like to collect in the form of YYYY-MM-DD (i.e. 2000-05-15): ")
granularity = input("Enter the granularity of data you'd like to collect (i.e. H1): ")
count = int(input('Enter the number of data points you want to collect (i.e. 100): '))
ohana = Oanda(instrument, start, granularity, count)
ohana.acquire_data()
df = ohana.normalize_return_data()
# Out:
# What pair would you like to trade (i.e. EUR_USD): EUR_USD
# Enter the start date of data you'd like to collect in the form of YYYY-MM-DD (i.e. 2000-05-15): 2000-05-15
# Enter the granularity of data you'd like to collect (i.e. H1): H1
# Enter the number of data points you want to collect (i.e. 100): 100
# Custom dataset loaded.

# %%
class PlaceOrder(Oanda):
    """Finds tradeable pairs and places custom buy and sell orders!"""
    def __init__(self, instrument, start, granularity, count, Type):
        Oanda.__init__(self, instrument, start, granularity, count)
        self.Type = Type
    
    def get_pairs(self, Type, instrument): # check whether a given pair can be currently traded on Oanda
        xml = urllib.request.urlopen("https://www.oanda.com/forex-trading/markets/live").read().decode("utf-8") # opens URL with asset options
        forex = re.findall("[A-WY-Z]{3}/[A-WY-Z]{3}",xml) # finds all Forex trading pairs (none start with an 'X')
        metals = re.findall("[X][A-Z]{2}/[A-Z]{3}",xml) # finds all metals (they all start with an 'X')
        dct_of_trading_pairs = {"Forex": forex, "Metals": metals} # puts the above into a dict, values are lists
        return dct_of_trading_pairs[Type][29] # return EUR_USD for example
    
    def create_order(self, instrument, units): # Functionality: Place order of 100 units of pair with our account ID.
        response = Oanda.api.order.market(ohana.attr, instrument = instrument, units = units)
        print("Response: {} ({})".format(response.status, response.reason))
        
    def create_sell_order(self, instrument, units): # Functionality: Place sell order of 100 units of pair with our account ID.
        response = Oanda.api.order.market(ohana.attr, instrument = instrument, units = -units)
        print("Response: {} ({})".format(response.status, response.reason))

order = PlaceOrder("Forex", ohana.start, ohana.granularity, ohana.count, ohana.instrument)
order.get_pairs("Forex", ohana.instrument)
order.create_order(ohana.instrument, ohana.count)
order.create_sell_order(ohana.instrument, ohana.count)
# Out:
# Response: 201 (Created)
# Response: 201 (Created)

# %%
class Strategy(Oanda):
    """Places 10 example orders according to random strategy to demonstrate program."""
    def __init__(self, instrument, start, granularity, count, df, time_wait):
        Oanda.__init__(self, instrument, start, granularity, count)
        self.df = df
        self.time_wait = time_wait

    def create_order(self, df, time_wait): # polymorphous function
        t0 = time.monotonic()
        # placeholder for profitable strategy:
        for i in range(self.time_wait):
            number = random.randrange(self.time_wait)
            t0 += 1
            time.sleep(t0 - time.monotonic())
            # to trade:
            if number > 4:
                order.create_order(instrument=self.instrument, units=self.count)
            elif number <= 4:
                order.create_sell_order(instrument=self.instrument, units=self.count)

strat = Strategy(ohana.instrument, ohana.start, ohana.granularity, ohana.count, ohana.normalize_return_data(), 10)
print("Generating 10 market buy and sell orders according to random strategy: ")
strat.create_order(ohana.normalize_return_data(), 10) # polymorphism, same name across classes
# Out:
# Custom dataset loaded.
# Generating 10 market buy and sell orders according to random strategy:
# Custom dataset loaded.
# Response: 201 (Created)
# Response: 201 (Created)
# Response: 201 (Created)
# Response: 201 (Created)
# Response: 201 (Created)
# Response: 201 (Created)
# Response: 201 (Created)
# Response: 201 (Created)
# Response: 201 (Created)
# Response: 201 (Created)

# %%
class Log(Strategy):
    """Write order information to text file: Date, amount, price, ID, etc."""
    def __init__(self, account, prices):
        self.account = account
        self.prices = prices
    
    def get_acct(self):
        response = Oanda.api.account.get(ohana.attr)
        file = open("file.txt", "a")
        file.write(str(response.get(self.account, 200)))
        file.close()
        
    def get_prices(self): # Functionality: Check current price using GET
        response = Oanda.api.pricing.get(ohana.attr, instruments=ohana.instrument)
        file = open("file.txt", "a") 
        for price in response.get(self.prices, 200): # returns 'Price' object
            file.write(str(price))
        file.close()
        for price in response.get(self.prices, 200):
            return str(price)

    def read_txt(self):
        file = open("file.txt", "r") 
        return file.read() 
    
    def bid_ask_spread(self):
        bid_price_isolation = log.get_prices()[log.get_prices().find("bids:")+15:log.get_prices().find("bids:")+22]
        ask_price_isolation = log.get_prices()[log.get_prices().find("asks:")+15:log.get_prices().find("asks:")+22]
        file = open("file.txt", "a") 
        file.write("Bid ask spread is " + str(float(ask_price_isolation) - float(bid_price_isolation)))
        file.close()
        return float(ask_price_isolation) - float(bid_price_isolation)
    
    # operator overloading:
    def __sub__(self, other):
        return float(self) - float(other)
    
    def __str__(self): # CONVERT PRICE OR OTHER OANDA OBJECT TO STRING TO THEN WRITE TO FILE
        return str(self)
    
    def __repr__(self): # CONVERT PRICE TO CUSTOM STRING TO DISPLAY
        return "Price(" + str(self) + "')"
    
    def __float__(self):
        return float(self)
    
log = Log("account", "prices")
log.get_acct()
log.get_prices()
log.bid_ask_spread()

view = input('Type in L to view the log file, otherwise press enter: ').upper()
if view == 'L':
    print(log.read_txt())
# Out:
# Type in L to view the log file, otherwise press enter: L
# id: 101-001-7843068-001
# alias: Primary
# currency: USD
# balance: 99880.9294
# createdByUserID: 7843068
# createdTime: '2018-02-20T17:51:16.415341547Z'
# pl: -94.845
# resettablePL: -94.845
# commission: 0.0
# marginRate: 0.02
# openTradeCount: 260
# openPositionCount: 2
# pendingOrderCount: 0
# hedgingEnabled: false
# unrealizedPL: -7678.01
# NAV: 92202.9194
# marginUsed: 15709.8058
# marginAvailable: 76493.1136
# positionValue: 533658.288
# marginCloseoutUnrealizedPL: -7610.586
# marginCloseoutNAV: 92270.3434
# marginCloseoutMarginUsed: 15709.8058
# marginCloseoutPercent: 0.08513
# marginCloseoutPositionValue: 533658.288
# withdrawalLimit: 76493.1136
# marginCallMarginUsed: 15709.8058
# marginCallPercent: 0.17026
# lastTransactionID: '906'
# trades:
# - id: '163'
#   instrument: EUR_USD
#   price: 1.22342
#   openTime: '2018-02-28T01:17:57.467420003Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.422
#   financing: -0.006
# - id: '167'
#   instrument: EUR_USD
#   price: 1.22347
#   openTime: '2018-02-28T01:18:04.337128638Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.427
#   financing: -0.006
# - id: '169'
#   instrument: EUR_USD
#   price: 1.22347
#   openTime: '2018-02-28T01:18:05.341069773Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.427
#   financing: -0.006
# - id: '171'
#   instrument: EUR_USD
#   price: 1.22347
#   openTime: '2018-02-28T01:18:06.329904162Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.427
#   financing: -0.006
# - id: '173'
#   instrument: EUR_USD
#   price: 1.22341
#   openTime: '2018-02-28T01:18:07.341985095Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.421
#   financing: -0.006
# - id: '177'
#   instrument: EUR_USD
#   price: 1.22345
#   openTime: '2018-02-28T01:18:09.339839358Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.425
#   financing: -0.006
# - id: '179'
#   instrument: EUR_USD
#   price: 1.22345
#   openTime: '2018-02-28T01:18:10.350704864Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.425
#   financing: -0.006
# - id: '183'
#   instrument: EUR_USD
#   price: 1.22348
#   openTime: '2018-02-28T01:18:12.335409693Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.428
#   financing: -0.006
# - id: '187'
#   instrument: EUR_USD
#   price: 1.22342
#   openTime: '2018-02-28T01:18:14.339746044Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.422
#   financing: -0.006
# - id: '189'
#   instrument: EUR_USD
#   price: 1.22336
#   openTime: '2018-02-28T01:18:15.351867886Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.416
#   financing: -0.006
# - id: '191'
#   instrument: EUR_USD
#   price: 1.22336
#   openTime: '2018-02-28T01:18:16.345553275Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.416
#   financing: -0.006
# - id: '193'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:18:17.338348793Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '195'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:18:18.349098023Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '197'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:18:19.340272868Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '199'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:18:20.337077485Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '203'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:22.339124032Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '205'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:23.331262533Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '207'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:24.339603567Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '209'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:25.344374955Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '211'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:26.337682387Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '213'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:27.338656080Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '215'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:28.339829423Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '217'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:29.331084435Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '219'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:30.336176834Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '221'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:31.337552423Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '223'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:32.332026613Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '225'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:18:33.335727232Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '227'
#   instrument: EUR_USD
#   price: 1.22321
#   openTime: '2018-02-28T01:20:21.627937355Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.401
#   financing: -0.006
# - id: '233'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:24.631315351Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '235'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:25.637832656Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '237'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:26.620341218Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '239'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:27.624907424Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '241'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:28.623178171Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '243'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:29.663438611Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '245'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:30.632070753Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '247'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:31.630121161Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '251'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:33.627692766Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '253'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:34.632900978Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '255'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:35.622709712Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '257'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:20:36.619666207Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.006
# - id: '263'
#   instrument: EUR_USD
#   price: 1.22328
#   openTime: '2018-02-28T01:20:39.619976010Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.408
#   financing: -0.006
# - id: '265'
#   instrument: EUR_USD
#   price: 1.22329
#   openTime: '2018-02-28T01:20:40.620802939Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.409
#   financing: -0.006
# - id: '267'
#   instrument: EUR_USD
#   price: 1.22329
#   openTime: '2018-02-28T01:20:41.630777180Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.409
#   financing: -0.006
# - id: '269'
#   instrument: EUR_USD
#   price: 1.22329
#   openTime: '2018-02-28T01:20:42.645337206Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.409
#   financing: -0.006
# - id: '271'
#   instrument: EUR_USD
#   price: 1.22326
#   openTime: '2018-02-28T01:20:43.630623220Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.406
#   financing: -0.006
# - id: '273'
#   instrument: EUR_USD
#   price: 1.22326
#   openTime: '2018-02-28T01:20:44.645883749Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.406
#   financing: -0.006
# - id: '275'
#   instrument: EUR_USD
#   price: 1.22325
#   openTime: '2018-02-28T01:20:45.634246828Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.405
#   financing: -0.006
# - id: '277'
#   instrument: EUR_USD
#   price: 1.22325
#   openTime: '2018-02-28T01:20:46.616276317Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.405
#   financing: -0.006
# - id: '279'
#   instrument: EUR_USD
#   price: 1.22325
#   openTime: '2018-02-28T01:20:47.631871551Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.405
#   financing: -0.006
# - id: '281'
#   instrument: EUR_USD
#   price: 1.22326
#   openTime: '2018-02-28T01:20:48.618868292Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.406
#   financing: -0.006
# - id: '283'
#   instrument: EUR_USD
#   price: 1.22326
#   openTime: '2018-02-28T01:20:49.619422910Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.406
#   financing: -0.006
# - id: '285'
#   instrument: EUR_USD
#   price: 1.22326
#   openTime: '2018-02-28T01:20:50.637954318Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.406
#   financing: -0.006
# - id: '287'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:10.936356232Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '289'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:11.746642985Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '291'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:12.747324163Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '293'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:13.741459737Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '297'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:15.756880720Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '299'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:16.741334662Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '301'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:17.774218315Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '303'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:18.758578215Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '305'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:19.803716237Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '307'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:27:20.744329613Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.006
# - id: '311'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:22.744521001Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '315'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:24.740075039Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '317'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:25.754169875Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '319'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:26.751565884Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '321'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:27.741876436Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '325'
#   instrument: EUR_USD
#   price: 1.22339
#   openTime: '2018-02-28T01:27:29.751515339Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.419
#   financing: -0.006
# - id: '329'
#   instrument: EUR_USD
#   price: 1.22332
#   openTime: '2018-02-28T01:27:31.751048250Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.412
#   financing: -0.006
# - id: '333'
#   instrument: EUR_USD
#   price: 1.22332
#   openTime: '2018-02-28T01:27:33.753901670Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.412
#   financing: -0.006
# - id: '335'
#   instrument: EUR_USD
#   price: 1.22334
#   openTime: '2018-02-28T01:27:34.745459067Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.414
#   financing: -0.006
# - id: '337'
#   instrument: EUR_USD
#   price: 1.22334
#   openTime: '2018-02-28T01:27:35.750208432Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.414
#   financing: -0.006
# - id: '339'
#   instrument: EUR_USD
#   price: 1.22334
#   openTime: '2018-02-28T01:27:36.740354336Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.414
#   financing: -0.006
# - id: '341'
#   instrument: EUR_USD
#   price: 1.22334
#   openTime: '2018-02-28T01:27:37.745759162Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.414
#   financing: -0.006
# - id: '343'
#   instrument: EUR_USD
#   price: 1.22333
#   openTime: '2018-02-28T01:27:38.752387544Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.413
#   financing: -0.006
# - id: '345'
#   instrument: EUR_USD
#   price: 1.22333
#   openTime: '2018-02-28T01:27:39.741589695Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.413
#   financing: -0.006
# - id: '347'
#   instrument: EUR_USD
#   price: 1.22325
#   openTime: '2018-02-28T01:34:15.256508807Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.405
#   financing: -0.0059
# - id: '355'
#   instrument: EUR_USD
#   price: 1.2233
#   openTime: '2018-02-28T01:34:21.289780062Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.41
#   financing: -0.0059
# - id: '357'
#   instrument: EUR_USD
#   price: 1.2233
#   openTime: '2018-02-28T01:34:22.274201541Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.41
#   financing: -0.0059
# - id: '359'
#   instrument: EUR_USD
#   price: 1.22332
#   openTime: '2018-02-28T01:34:23.283758879Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.412
#   financing: -0.0059
# - id: '361'
#   instrument: EUR_USD
#   price: 1.22333
#   openTime: '2018-02-28T01:34:24.287543960Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.413
#   financing: -0.0059
# - id: '363'
#   instrument: EUR_USD
#   price: 1.22336
#   openTime: '2018-02-28T01:34:25.363260712Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.416
#   financing: -0.0059
# - id: '367'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:27.280683720Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '369'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:28.285739714Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '371'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:29.275888749Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '373'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:30.278198824Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '375'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:31.284922486Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '377'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:32.291385260Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '379'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:33.280016165Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '381'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:34.297135446Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '387'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:37.278012186Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '389'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:38.290898611Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '393'
#   instrument: EUR_USD
#   price: 1.22335
#   openTime: '2018-02-28T01:34:40.286121067Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.415
#   financing: -0.0059
# - id: '395'
#   instrument: EUR_USD
#   price: 1.22341
#   openTime: '2018-02-28T01:34:41.283143115Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.421
#   financing: -0.0059
# - id: '401'
#   instrument: EUR_USD
#   price: 1.22337
#   openTime: '2018-02-28T01:34:44.283700415Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.417
#   financing: -0.0059
# - id: '403'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:34:45.330977637Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.0059
# - id: '405'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:34:46.273146912Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.0059
# - id: '407'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:34:47.292879941Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.0059
# - id: '409'
#   instrument: EUR_USD
#   price: 1.22338
#   openTime: '2018-02-28T01:34:48.286844687Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.418
#   financing: -0.0059
# - id: '411'
#   instrument: EUR_USD
#   price: 1.22333
#   openTime: '2018-02-28T01:35:10.770260904Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.413
#   financing: -0.0059
# - id: '417'
#   instrument: EUR_USD
#   price: 1.22328
#   openTime: '2018-02-28T01:35:13.165889463Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.408
#   financing: -0.0059
# - id: '419'
#   instrument: EUR_USD
#   price: 1.22328
#   openTime: '2018-02-28T01:35:14.168770724Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.408
#   financing: -0.0059
# - id: '421'
#   instrument: EUR_USD
#   price: 1.22328
#   openTime: '2018-02-28T01:35:15.164929889Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.408
#   financing: -0.0059
# - id: '423'
#   instrument: EUR_USD
#   price: 1.22328
#   openTime: '2018-02-28T01:35:16.262008433Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.408
#   financing: -0.0059
# - id: '425'
#   instrument: EUR_USD
#   price: 1.22328
#   openTime: '2018-02-28T01:35:17.166073123Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.408
#   financing: -0.0059
# - id: '429'
#   instrument: EUR_USD
#   price: 1.22328
#   openTime: '2018-02-28T01:35:19.158683413Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.408
#   financing: -0.0059
# - id: '431'
#   instrument: EUR_USD
#   price: 1.22328
#   openTime: '2018-02-28T01:35:20.158906036Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.408
#   financing: -0.0059
# - id: '437'
#   instrument: EUR_USD
#   price: 1.22328
#   openTime: '2018-02-28T01:35:23.157907952Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.408
#   financing: -0.0059
# - id: '441'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:35:25.162991555Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.0059
# - id: '443'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:35:26.235287495Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.0059
# - id: '445'
#   instrument: EUR_USD
#   price: 1.22322
#   openTime: '2018-02-28T01:35:27.144265085Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.402
#   financing: -0.0059
# - id: '447'
#   instrument: EUR_USD
#   price: 1.22321
#   openTime: '2018-02-28T01:35:28.150354967Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.401
#   financing: -0.0059
# - id: '451'
#   instrument: EUR_USD
#   price: 1.22321
#   openTime: '2018-02-28T01:35:30.159755182Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.401
#   financing: -0.0059
# - id: '457'
#   instrument: EUR_USD
#   price: 1.22314
#   openTime: '2018-02-28T01:35:33.149754687Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.394
#   financing: -0.0059
# - id: '459'
#   instrument: EUR_USD
#   price: 1.22314
#   openTime: '2018-02-28T01:35:34.152856149Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.394
#   financing: -0.0059
# - id: '463'
#   instrument: EUR_USD
#   price: 1.22308
#   openTime: '2018-02-28T01:35:36.229227186Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.388
#   financing: -0.0059
# - id: '465'
#   instrument: EUR_USD
#   price: 1.22308
#   openTime: '2018-02-28T01:35:37.158216625Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.388
#   financing: -0.0059
# - id: '467'
#   instrument: EUR_USD
#   price: 1.22308
#   openTime: '2018-02-28T01:35:38.158907100Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.388
#   financing: -0.0059
# - id: '469'
#   instrument: EUR_USD
#   price: 1.22308
#   openTime: '2018-02-28T01:35:39.158426339Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.388
#   financing: -0.0059
# - id: '473'
#   instrument: EUR_USD
#   price: 1.22308
#   openTime: '2018-02-28T01:35:41.150714775Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.388
#   financing: -0.0059
# - id: '475'
#   instrument: EUR_USD
#   price: 1.22253
#   openTime: '2018-02-28T04:15:39.944319184Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.333
#   financing: -0.0051
# - id: '481'
#   instrument: EUR_USD
#   price: 1.22258
#   openTime: '2018-02-28T04:15:44.923048903Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.338
#   financing: -0.0051
# - id: '487'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:15:47.920811399Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '489'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:15:48.933506689Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '491'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:15:49.909091499Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '493'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:15:50.910370041Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '495'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:15:51.913697035Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '497'
#   instrument: EUR_USD
#   price: 1.22253
#   openTime: '2018-02-28T04:15:52.897817796Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.333
#   financing: -0.0051
# - id: '499'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:15:53.926012562Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '501'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:15:54.945740752Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '505'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:15:56.926241834Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '507'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:15:57.911149052Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '509'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:15:58.916775874Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '511'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:15:59.914564579Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '513'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:00.920042916Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '515'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:01.903791557Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '517'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:02.913025869Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '519'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:03.906506846Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '521'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:04.901532444Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '523'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:05.940880325Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '525'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:06.929843385Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '527'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:07.921223438Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '529'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:08.911924292Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '533'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:10.912343900Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '535'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:11.932163994Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '539'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:38.252601256Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '541'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:39.261489450Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '543'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:40.263812657Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '545'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:41.261418414Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '555'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:46.264962684Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '557'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:16:47.258323732Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '559'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:17:31.498735812Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '563'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:17:33.515996997Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '565'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:17:34.517990162Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '567'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:17:35.522734300Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '571'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:17:37.520097287Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '573'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:17:38.508982074Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '577'
#   instrument: EUR_USD
#   price: 1.22254
#   openTime: '2018-02-28T04:17:40.517740145Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.334
#   financing: -0.0051
# - id: '579'
#   instrument: EUR_USD
#   price: 1.22259
#   openTime: '2018-02-28T04:20:31.034982382Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.339
#   financing: -0.0051
# - id: '583'
#   instrument: EUR_USD
#   price: 1.22258
#   openTime: '2018-02-28T04:20:35.551506922Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.338
#   financing: -0.0051
# - id: '589'
#   instrument: EUR_USD
#   price: 1.2226
#   openTime: '2018-02-28T04:20:38.545540346Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.34
#   financing: -0.0051
# - id: '595'
#   instrument: EUR_USD
#   price: 1.22258
#   openTime: '2018-02-28T04:20:41.544600545Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.338
#   financing: -0.0051
# - id: '599'
#   instrument: EUR_USD
#   price: 1.22258
#   openTime: '2018-02-28T04:20:43.546944601Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.338
#   financing: -0.0051
# - id: '603'
#   instrument: EUR_USD
#   price: 1.22255
#   openTime: '2018-02-28T04:22:59.007345092Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.335
#   financing: -0.0051
# - id: '607'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:23:27.310430149Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '611'
#   instrument: EUR_USD
#   price: 1.22251
#   openTime: '2018-02-28T04:23:30.762253525Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.331
#   financing: -0.0051
# - id: '615'
#   instrument: EUR_USD
#   price: 1.22252
#   openTime: '2018-02-28T04:23:32.765805727Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.332
#   financing: -0.0051
# - id: '621'
#   instrument: EUR_USD
#   price: 1.22252
#   openTime: '2018-02-28T04:23:35.763477230Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.332
#   financing: -0.0051
# - id: '625'
#   instrument: EUR_USD
#   price: 1.22252
#   openTime: '2018-02-28T04:23:37.848028954Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.332
#   financing: -0.0051
# - id: '627'
#   instrument: EUR_USD
#   price: 1.22252
#   openTime: '2018-02-28T04:23:38.780327702Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.332
#   financing: -0.0051
# - id: '629'
#   instrument: EUR_USD
#   price: 1.22252
#   openTime: '2018-02-28T04:23:39.843611762Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.332
#   financing: -0.0051
# - id: '631'
#   instrument: EUR_USD
#   price: 1.22233
#   openTime: '2018-02-28T04:44:43.434449304Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.313
#   financing: -0.0049
# - id: '637'
#   instrument: EUR_USD
#   price: 1.22239
#   openTime: '2018-02-28T04:45:59.495958440Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.319
#   financing: -0.0049
# - id: '641'
#   instrument: EUR_USD
#   price: 1.22239
#   openTime: '2018-02-28T04:46:01.489365673Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.319
#   financing: -0.0049
# - id: '643'
#   instrument: EUR_USD
#   price: 1.22239
#   openTime: '2018-02-28T04:46:02.493652039Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.319
#   financing: -0.0049
# - id: '645'
#   instrument: EUR_USD
#   price: 1.22239
#   openTime: '2018-02-28T04:46:03.479362571Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.319
#   financing: -0.0049
# - id: '647'
#   instrument: EUR_USD
#   price: 1.22239
#   openTime: '2018-02-28T04:46:04.482537659Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.319
#   financing: -0.0049
# - id: '649'
#   instrument: EUR_USD
#   price: 1.22239
#   openTime: '2018-02-28T04:46:05.492236497Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.319
#   financing: -0.0049
# - id: '651'
#   instrument: EUR_USD
#   price: 1.22239
#   openTime: '2018-02-28T04:46:06.489775839Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.319
#   financing: -0.0049
# - id: '653'
#   instrument: EUR_USD
#   price: 1.22239
#   openTime: '2018-02-28T04:46:07.504040882Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.319
#   financing: -0.0049
# - id: '655'
#   instrument: EUR_USD
#   price: 1.22226
#   openTime: '2018-02-28T04:47:44.248168311Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.306
#   financing: -0.0049
# - id: '659'
#   instrument: EUR_USD
#   price: 1.22226
#   openTime: '2018-02-28T04:47:46.255224897Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.306
#   financing: -0.0049
# - id: '663'
#   instrument: EUR_USD
#   price: 1.22231
#   openTime: '2018-02-28T04:47:48.286990612Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.311
#   financing: -0.0049
# - id: '667'
#   instrument: EUR_USD
#   price: 1.22231
#   openTime: '2018-02-28T04:47:50.291533870Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.311
#   financing: -0.0049
# - id: '669'
#   instrument: EUR_USD
#   price: 1.22231
#   openTime: '2018-02-28T04:47:51.265109399Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.311
#   financing: -0.0049
# - id: '673'
#   instrument: EUR_USD
#   price: 1.22231
#   openTime: '2018-02-28T04:47:53.252063264Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.311
#   financing: -0.0049
# - id: '677'
#   instrument: EUR_USD
#   price: 1.22229
#   openTime: '2018-02-28T04:49:16.861768842Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.309
#   financing: -0.0049
# - id: '683'
#   instrument: EUR_USD
#   price: 1.22229
#   openTime: '2018-02-28T04:49:19.873024506Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.309
#   financing: -0.0049
# - id: '685'
#   instrument: EUR_USD
#   price: 1.22229
#   openTime: '2018-02-28T04:49:20.870908681Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.309
#   financing: -0.0049
# - id: '689'
#   instrument: EUR_USD
#   price: 1.22229
#   openTime: '2018-02-28T04:49:22.860510321Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.309
#   financing: -0.0049
# - id: '691'
#   instrument: EUR_USD
#   price: 1.22229
#   openTime: '2018-02-28T04:49:23.873473685Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.309
#   financing: -0.0049
# - id: '695'
#   instrument: EUR_USD
#   price: 1.22234
#   openTime: '2018-02-28T04:49:51.502908684Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.314
#   financing: -0.0049
# - id: '697'
#   instrument: EUR_USD
#   price: 1.22234
#   openTime: '2018-02-28T04:49:52.503659233Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.314
#   financing: -0.0049
# - id: '699'
#   instrument: EUR_USD
#   price: 1.22234
#   openTime: '2018-02-28T04:49:53.482755452Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.314
#   financing: -0.0049
# - id: '701'
#   instrument: EUR_USD
#   price: 1.22234
#   openTime: '2018-02-28T04:49:54.485063974Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.314
#   financing: -0.0049
# - id: '709'
#   instrument: EUR_USD
#   price: 1.22234
#   openTime: '2018-02-28T04:49:58.489163294Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.314
#   financing: -0.0049
# - id: '711'
#   instrument: EUR_USD
#   price: 1.22234
#   openTime: '2018-02-28T04:49:59.483263555Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.314
#   financing: -0.0049
# - id: '716'
#   instrument: EUR_USD
#   price: 1.21872
#   openTime: '2018-03-01T00:37:39.209945796Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.048
#   financing: 0.0
# - id: '720'
#   instrument: EUR_USD
#   price: 1.21872
#   openTime: '2018-03-01T00:37:40.434597464Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.048
#   financing: 0.0
# - id: '726'
#   instrument: EUR_USD
#   price: 1.21867
#   openTime: '2018-03-01T00:37:43.450998577Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.053
#   financing: 0.0
# - id: '728'
#   instrument: EUR_USD
#   price: 1.21867
#   openTime: '2018-03-01T00:37:44.454824693Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.053
#   financing: 0.0
# - id: '734'
#   instrument: EUR_USD
#   price: 1.21868
#   openTime: '2018-03-01T00:37:47.488013266Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.052
#   financing: 0.0
# - id: '740'
#   instrument: EUR_USD
#   price: 1.21866
#   openTime: '2018-03-01T00:38:28.081028256Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.054
#   financing: 0.0
# - id: '746'
#   instrument: EUR_USD
#   price: 1.21867
#   openTime: '2018-03-01T00:38:34.564793312Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.053
#   financing: 0.0
# - id: '748'
#   instrument: EUR_USD
#   price: 1.21867
#   openTime: '2018-03-01T00:38:35.567514387Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.053
#   financing: 0.0
# - id: '750'
#   instrument: EUR_USD
#   price: 1.21869
#   openTime: '2018-03-01T00:38:36.577663273Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.051
#   financing: 0.0
# - id: '758'
#   instrument: EUR_USD
#   price: 1.21869
#   openTime: '2018-03-01T00:38:40.577041092Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.051
#   financing: 0.0
# - id: '760'
#   instrument: EUR_USD
#   price: 1.21869
#   openTime: '2018-03-01T00:38:41.575283123Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.051
#   financing: 0.0
# - id: '762'
#   instrument: EUR_USD
#   price: 1.21869
#   openTime: '2018-03-01T00:38:42.577199235Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.051
#   financing: 0.0
# - id: '766'
#   instrument: EUR_USD
#   price: 1.21864
#   openTime: '2018-03-01T00:38:48.646069852Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.056
#   financing: 0.0
# - id: '770'
#   instrument: EUR_USD
#   price: 1.21864
#   openTime: '2018-03-01T00:38:50.649010603Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.056
#   financing: 0.0
# - id: '778'
#   instrument: EUR_USD
#   price: 1.21866
#   openTime: '2018-03-01T00:38:54.643776297Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.054
#   financing: 0.0
# - id: '780'
#   instrument: EUR_USD
#   price: 1.21866
#   openTime: '2018-03-01T00:38:55.641859443Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.054
#   financing: 0.0
# - id: '782'
#   instrument: EUR_USD
#   price: 1.21866
#   openTime: '2018-03-01T00:38:56.642151096Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.054
#   financing: 0.0
# - id: '784'
#   instrument: EUR_USD
#   price: 1.21875
#   openTime: '2018-03-01T02:08:45.479949215Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.045
#   financing: 0.0
# - id: '788'
#   instrument: EUR_USD
#   price: 1.21889
#   openTime: '2018-03-01T02:09:44.502837324Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.031
#   financing: 0.0
# - id: '792'
#   instrument: EUR_USD
#   price: 1.2191
#   openTime: '2018-03-01T02:15:31.636285180Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.01
#   financing: 0.0
# - id: '796'
#   instrument: EUR_USD
#   price: 1.2191
#   openTime: '2018-03-01T02:15:33.481940532Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.01
#   financing: 0.0
# - id: '798'
#   instrument: EUR_USD
#   price: 1.2191
#   openTime: '2018-03-01T02:15:34.480783524Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.01
#   financing: 0.0
# - id: '800'
#   instrument: EUR_USD
#   price: 1.2191
#   openTime: '2018-03-01T02:15:35.481451084Z'
#   state: OPEN
# ...
#   price: 1.21935
#   openTime: '2018-03-01T02:52:22.307114542Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.781
#   financing: -0.0055
# - id: '898'
#   instrument: EUR_USD
#   price: 1.21935
#   openTime: '2018-03-01T02:52:23.315147358Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.781
#   financing: -0.0055
# - id: '902'
#   instrument: EUR_USD
#   price: 1.21935
#   openTime: '2018-03-01T02:52:25.310832139Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.781
#   financing: -0.0055
# - id: '904'
#   instrument: EUR_USD
#   price: 1.21935
#   openTime: '2018-03-01T02:52:26.299021862Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.781
#   financing: -0.0055
# - id: '906'
#   instrument: EUR_USD
#   price: 1.21935
#   openTime: '2018-03-01T02:52:27.321040743Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.781
#   financing: -0.0055
# - id: '908'
#   instrument: EUR_USD
#   price: 1.21912
#   openTime: '2018-03-01T02:53:54.593343417Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.804
#   financing: -0.0055
# - id: '912'
#   instrument: EUR_USD
#   price: 1.21912
#   openTime: '2018-03-01T02:53:55.764237992Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.804
#   financing: -0.0055
# - id: '922'
#   instrument: EUR_USD
#   price: 1.21912
#   openTime: '2018-03-01T02:54:00.820890244Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.804
#   financing: -0.0055
# - id: '926'
#   instrument: EUR_USD
#   price: 1.21912
#   openTime: '2018-03-01T02:54:02.758582135Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.804
#   financing: -0.0055
# - id: '928'
#   instrument: EUR_USD
#   price: 1.21912
#   openTime: '2018-03-01T02:54:03.758584265Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.804
#   financing: -0.0055
# - id: '932'
#   instrument: EUR_USD
#   price: 1.21922
#   openTime: '2018-03-01T02:56:37.522710500Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.794
#   financing: -0.0055
# - id: '938'
#   instrument: EUR_USD
#   price: 1.21922
#   openTime: '2018-03-01T02:56:39.881275469Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.794
#   financing: -0.0055
# - id: '940'
#   instrument: EUR_USD
#   price: 1.21922
#   openTime: '2018-03-01T02:56:40.881763076Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.794
#   financing: -0.0055
# - id: '948'
#   instrument: EUR_USD
#   price: 1.21922
#   openTime: '2018-03-01T02:56:44.870317476Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.794
#   financing: -0.0055
# - id: '952'
#   instrument: EUR_USD
#   price: 1.21922
#   openTime: '2018-03-01T02:56:46.920528168Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.794
#   financing: -0.0055
# - id: '954'
#   instrument: EUR_USD
#   price: 1.21922
#   openTime: '2018-03-01T02:56:47.861065656Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.794
#   financing: -0.0055
# - id: '956'
#   instrument: EUR_USD
#   price: 1.22056
#   openTime: '2018-03-01T15:41:58.113678570Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.66
#   financing: -0.0016
# - id: '960'
#   instrument: EUR_USD
#   price: 1.22055
#   openTime: '2018-03-01T15:42:01.201866380Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.661
#   financing: -0.0016
# - id: '964'
#   instrument: EUR_USD
#   price: 1.2205
#   openTime: '2018-03-01T15:42:03.198847953Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.666
#   financing: -0.0016
# - id: '970'
#   instrument: EUR_USD
#   price: 1.22051
#   openTime: '2018-03-01T15:42:06.204849890Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.665
#   financing: -0.0016
# - id: '972'
#   instrument: EUR_USD
#   price: 1.22051
#   openTime: '2018-03-01T15:42:07.209887244Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.665
#   financing: -0.0016
# - id: '974'
#   instrument: EUR_USD
#   price: 1.22051
#   openTime: '2018-03-01T15:42:08.209604682Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: 0.665
#   financing: -0.0016
# - id: '981'
#   instrument: EUR_USD
#   price: 1.22736
#   openTime: '2018-03-01T22:46:27.453964984Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.02
#   financing: 0.0
# - id: '985'
#   instrument: EUR_USD
#   price: 1.22735
#   openTime: '2018-03-01T22:46:35.295681590Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.019
#   financing: 0.0
# - id: '999'
#   instrument: EUR_USD
#   price: 1.22735
#   openTime: '2018-03-01T22:46:42.289152813Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.019
#   financing: 0.0
# - id: '1003'
#   instrument: EUR_USD
#   price: 1.22735
#   openTime: '2018-03-01T22:46:44.302741645Z'
#   state: OPEN
#   initialUnits: 100.0
#   currentUnits: 100.0
#   realizedPL: 0.0
#   unrealizedPL: -0.019
#   financing: 0.0
# - id: '57'
#   instrument: NZD_USD
#   price: 0.72882
#   openTime: '2018-02-25T23:16:08.253712465Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -148.5
#   financing: -2.1968
# - id: '59'
#   instrument: NZD_USD
#   price: 0.72882
#   openTime: '2018-02-25T23:16:39.545282683Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -148.5
#   financing: -2.1966
# - id: '61'
#   instrument: NZD_USD
#   price: 0.72843
#   openTime: '2018-02-25T23:26:56.583952074Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -129.0
#   financing: -2.1892
# - id: '63'
#   instrument: NZD_USD
#   price: 0.7299
#   openTime: '2018-02-26T01:38:21.614818988Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -202.5
#   financing: -2.1516
# - id: '65'
#   instrument: NZD_USD
#   price: 0.72996
#   openTime: '2018-02-26T01:38:41.714367646Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -205.5
#   financing: -2.152
# - id: '67'
#   instrument: NZD_USD
#   price: 0.73001
#   openTime: '2018-02-26T01:38:51.860847594Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -208.0
#   financing: -2.1523
# - id: '69'
#   instrument: NZD_USD
#   price: 0.73345
#   openTime: '2018-02-26T05:36:49.010726195Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -380.0
#   financing: -2.0892
# - id: '71'
#   instrument: NZD_USD
#   price: 0.7337
#   openTime: '2018-02-26T05:37:53.213747835Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -392.5
#   financing: -2.091
# - id: '73'
#   instrument: NZD_USD
#   price: 0.73371
#   openTime: '2018-02-26T05:38:22.423259201Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -393.0
#   financing: -2.0907
# - id: '75'
#   instrument: NZD_USD
#   price: 0.73375
#   openTime: '2018-02-26T05:39:04.334805225Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -395.0
#   financing: -2.0909
# - id: '78'
#   instrument: NZD_USD
#   price: 0.72942
#   openTime: '2018-02-27T01:27:25.651476903Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -178.5
#   financing: -1.5949
# - id: '80'
#   instrument: NZD_USD
#   price: 0.72768
#   openTime: '2018-02-27T04:33:56.024023522Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -91.5
#   financing: -1.5108
# - id: '82'
#   instrument: NZD_USD
#   price: 0.72823
#   openTime: '2018-02-27T05:00:24.712065366Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -119.0
#   financing: -1.5039
# - id: '84'
#   instrument: NZD_USD
#   price: 0.72823
#   openTime: '2018-02-27T05:00:46.639205704Z'
#   state: OPEN
#   initialUnits: 50000.0
#   currentUnits: 50000.0
#   realizedPL: 0.0
#   unrealizedPL: -119.0
#   financing: -1.5038
# positions:
# - instrument: EUR_USD
#   pl: -99.348
#   unrealizedPL: 124.851
#   resettablePL: -99.348
#   commission: 0.0
#   long:
#     units: 24000.0
#     averagePrice: 1.22196
#     tradeIDs:
#     - '227'
#     - '233'
#     - '235'
#     - '237'
#     - '239'
#     - '241'
#     - '243'
#     - '245'
#     - '247'
#     - '251'
#     - '253'
#     - '255'
#     - '257'
#     - '263'
#     - '265'
#     - '267'
#     - '269'
#     - '271'
#     - '273'
#     - '275'
#     - '277'
#     - '279'
#     - '281'
#     - '283'
#     - '285'
#     - '287'
#     - '289'
#     - '291'
#     - '293'
#     - '297'
#     - '299'
#     - '301'
#     - '303'
#     - '305'
#     - '307'
#     - '311'
#     - '315'
#     - '317'
#     - '319'
#     - '321'
#     - '325'
#     - '329'
#     - '333'
#     - '335'
#     - '337'
#     - '339'
#     - '341'
#     - '343'
#     - '345'
#     - '347'
#     - '355'
#     - '357'
#     - '359'
#     - '361'
#     - '363'
#     - '367'
#     - '369'
#     - '371'
#     - '373'
#     - '375'
#     - '377'
#     - '379'
#     - '381'
#     - '387'
#     - '389'
#     - '393'
#     - '395'
#     - '401'
#     - '403'
#     - '405'
#     - '407'
#     - '409'
#     - '411'
#     - '417'
#     - '419'
#     - '421'
#     - '423'
#     - '425'
#     - '429'
#     - '431'
#     - '437'
#     - '441'
#     - '443'
#     - '445'
#     - '447'
#     - '451'
#     - '457'
#     - '459'
#     - '463'
#     - '465'
#     - '467'
#     - '469'
#     - '473'
#     - '475'
#     - '481'
#     - '487'
#     - '489'
#     - '491'
#     - '493'
#     - '495'
#     - '497'
#     - '499'
#     - '501'
#     - '505'
#     - '507'
#     - '509'
#     - '511'
#     - '513'
#     - '515'
#     - '517'
#     - '519'
#     - '521'
#     - '523'
#     - '525'
#     - '527'
#     - '529'
#     - '533'
#     - '535'
#     - '539'
#     - '541'
#     - '543'
#     - '545'
#     - '555'
#     - '557'
#     - '559'
#     - '563'
#     - '565'
#     - '567'
#     - '571'
#     - '573'
#     - '577'
#     - '579'
#     - '583'
#     - '589'
#     - '595'
#     - '599'
#     - '603'
#     - '607'
#     - '611'
#     - '615'
#     - '621'
#     - '625'
#     - '627'
#     - '629'
#     - '631'
#     - '637'
#     - '641'
#     - '643'
#     - '645'
#     - '647'
#     - '649'
#     - '651'
#     - '653'
#     - '655'
#     - '659'
#     - '663'
#     - '667'
#     - '669'
#     - '673'
#     - '677'
#     - '683'
#     - '685'
#     - '689'
#     - '691'
#     - '695'
#     - '697'
#     - '699'
#     - '701'
#     - '709'
#     - '711'
#     - '716'
#     - '720'
#     - '726'
#     - '728'
#     - '734'
#     - '740'
#     - '746'
#     - '748'
#     - '750'
#     - '758'
#     - '760'
#     - '762'
#     - '766'
#     - '770'
#     - '778'
#     - '780'
#     - '782'
#     - '784'
#     - '788'
#     - '792'
#     - '796'
#     - '798'
#     - '800'
#     - '804'
#     - '806'
#     - '808'
#     - '812'
#     - '816'
#     - '820'
#     - '824'
#     - '828'
#     - '832'
#     - '838'
#     - '842'
#     - '862'
#     - '864'
#     - '868'
#     - '870'
#     - '872'
#     - '876'
#     - '882'
#     - '884'
#     - '888'
#     - '892'
#     - '896'
#     - '898'
#     - '902'
#     - '904'
#     - '906'
#     - '908'
#     - '912'
#     - '922'
#     - '926'
#     - '928'
#     - '932'
#     - '938'
#     - '940'
#     - '948'
#     - '952'
#     - '954'
#     - '956'
#     - '960'
#     - '964'
#     - '970'
#     - '972'
#     - '974'
#     - '981'
#     - '985'
#     - '999'
#     - '1003'
#     pl: -99.348
#     unrealizedPL: 124.851
#     resettablePL: -99.348
#   short:
#     units: 0.0
#     pl: 0.0
#     unrealizedPL: 0.0
#     resettablePL: 0.0
# - instrument: NZD_USD
#   pl: 0.0
#   unrealizedPL: -3110.5
#   resettablePL: 0.0
#   commission: 0.0
#   long:
#     units: 700000.0
#     averagePrice: 0.73029
#     tradeIDs:
#     - '57'
#     - '59'
#     - '61'
#     - '63'
#     - '65'
#     - '67'
#     - '69'
#     - '71'
#     - '73'
#     - '75'
#     - '78'
#     - '80'
#     - '82'
#     - '84'
#     pl: 0.0
#     unrealizedPL: -3110.5
#     resettablePL: 0.0
#   short:
#     units: 0.0
#     pl: 0.0
#     unrealizedPL: 0.0
#     resettablePL: 0.0
# orders: []type: PRICE
# instrument: EUR_USD
# time: '2018-03-01T22:46:45.566758663Z'
# status: tradeable
# tradeable: true
# bids:
# - price: 1.22716
#   liquidity: 10000000
# asks:
# - price: 1.22734
#   liquidity: 10000000
# closeoutBid: 1.22701
# closeoutAsk: 1.22749
# quoteHomeConversionFactors:
#   positiveUnits: 1.0
#   negativeUnits: 1.0
# unitsAvailable:
#   default:
#     long: 3301937.0
#     short: 3349937.0
#   reduceFirst:
#     long: 3301937.0
#     short: 3349937.0
#   reduceOnly:
#     long: 0.0
#     short: 24000.0
#   openOnly:
#     long: 3301937.0
#     short: 0.0type: PRICE
# instrument: EUR_USD
# time: '2018-03-01T22:46:45.566758663Z'
# status: tradeable
# tradeable: true
# bids:
# - price: 1.22716
#   liquidity: 10000000
# asks:
# - price: 1.22734
#   liquidity: 10000000
# closeoutBid: 1.22701
# closeoutAsk: 1.22749
# quoteHomeConversionFactors:
#   positiveUnits: 1.0
#   negativeUnits: 1.0
# unitsAvailable:
#   default:
#     long: 3301937.0
#     short: 3349937.0
#   reduceFirst:
#     long: 3301937.0
#     short: 3349937.0
#   reduceOnly:
#     long: 0.0
#     short: 24000.0
#   openOnly:
#     long: 3301937.0
#     short: 0.0type: PRICE
# instrument: EUR_USD
# time: '2018-03-01T22:46:45.566758663Z'
# status: tradeable
# tradeable: true
# bids:
# - price: 1.22716
#   liquidity: 10000000
# asks:
# - price: 1.22734
#   liquidity: 10000000
# closeoutBid: 1.22701
# closeoutAsk: 1.22749
# quoteHomeConversionFactors:
#   positiveUnits: 1.0
#   negativeUnits: 1.0
# unitsAvailable:
#   default:
#     long: 3301937.0
#     short: 3349937.0
#   reduceFirst:
#     long: 3301937.0
#     short: 3349937.0
#   reduceOnly:
#     long: 0.0
#     short: 24000.0
#   openOnly:
#     long: 3301937.0
#     short: 0.0type: PRICE
# instrument: EUR_USD
# time: '2018-03-01T22:46:45.566758663Z'
# status: tradeable
# tradeable: true
# bids:
# - price: 1.22716
#   liquidity: 10000000
# asks:
# - price: 1.22734
#   liquidity: 10000000
# closeoutBid: 1.22701
# closeoutAsk: 1.22749
# quoteHomeConversionFactors:
#   positiveUnits: 1.0
#   negativeUnits: 1.0
# unitsAvailable:
#   default:
#     long: 3301937.0
#     short: 3349937.0
#   reduceFirst:
#     long: 3301937.0
#     short: 3349937.0
#   reduceOnly:
#     long: 0.0
#     short: 24000.0
#   openOnly:
#     long: 3301937.0
#     short: 0.0type: PRICE
# instrument: EUR_USD
# time: '2018-03-01T22:46:45.566758663Z'
# status: tradeable
# tradeable: true
# bids:
# - price: 1.22716
#   liquidity: 10000000
# asks:
# - price: 1.22734
#   liquidity: 10000000
# closeoutBid: 1.22701
# closeoutAsk: 1.22749
# quoteHomeConversionFactors:
#   positiveUnits: 1.0
#   negativeUnits: 1.0
# unitsAvailable:
#   default:
#     long: 3301937.0
#     short: 3349937.0
#   reduceFirst:
#     long: 3301937.0
#     short: 3349937.0
#   reduceOnly:
#     long: 0.0
#     short: 24000.0
#   openOnly:
#     long: 3301937.0
#     short: 0.0type: PRICE
# instrument: EUR_USD
# time: '2018-03-01T22:46:45.566758663Z'
# status: tradeable
# tradeable: true
# bids:
# - price: 1.22716
#   liquidity: 10000000
# asks:
# - price: 1.22734
#   liquidity: 10000000
# closeoutBid: 1.22701
# closeoutAsk: 1.22749
# quoteHomeConversionFactors:
#   positiveUnits: 1.0
#   negativeUnits: 1.0
# unitsAvailable:
#   default:
#     long: 3301937.0
#     short: 3349937.0
#   reduceFirst:
#     long: 3301937.0
#     short: 3349937.0
#   reduceOnly:
#     long: 0.0
#     short: 24000.0
#   openOnly:
#     long: 3301937.0
#     short: 0.0type: PRICE
# instrument: EUR_USD
# time: '2018-03-01T22:46:45.566758663Z'
# status: tradeable
# tradeable: true
# bids:
# - price: 1.22716
#   liquidity: 10000000
# asks:
# - price: 1.22734
#   liquidity: 10000000
# closeoutBid: 1.22701
# closeoutAsk: 1.22749
# quoteHomeConversionFactors:
#   positiveUnits: 1.0
#   negativeUnits: 1.0
# unitsAvailable:
#   default:
#     long: 3301937.0
#     short: 3349937.0
#   reduceFirst:
#     long: 3301937.0
#     short: 3349937.0
#   reduceOnly:
#     long: 0.0
#     short: 24000.0
#   openOnly:
#     long: 3301937.0
#     short: 0.0Bid ask spread is 0.000180000000000069
